# %%
# whether i will buy coffee or not in the cafe. on basis of coffe vendor, mood, alone or with someone.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
data=pd.read_csv("BuyMeACoffee.csv")
df=pd.DataFrame(data)
print(data.head())
# Out:
#   current_mood   weather  last_coffee_hours_ago taste_craving  \
# 0        Happy  Moderate                   10.0           Yes
# 1     Stressed       Hot                    7.1           Yes
# 2        Happy  Moderate                    2.9            No
# 3     Stressed  Moderate                    8.9           Yes
# 4        Tired       Hot                    1.0           Yes
#
#    distance_to_coffee_shop_km social_context buy_coffee
# 0                         3.7          Alone        Yes
# 1                         1.0   With Friends        Yes
# 2                         4.6          Alone         No
# 3                         1.3          Alone        Yes
# 4                         0.6          Alone        Yes

# %%
LabelEncoder=LabelEncoder()
for column in df.columns:
  df[column]=LabelEncoder.fit_transform(df[column])
print(df)
# Out:
#       current_mood  weather  last_coffee_hours_ago  taste_craving  \
# 0                0        2                    100              1
# 1                1        1                     71              1
# 2                0        2                     29              0
# 3                1        2                     89              1
# 4                2        1                     10              1
# ...            ...      ...                    ...            ...
# 1495             1        2                     43              1
# 1496             0        2                     57              0
# 1497             1        0                     59              0
# 1498             2        1                    103              0
# 1499             1        0                     92              0
#
#       distance_to_coffee_shop_km  social_context  buy_coffee
# 0                             36               0           1
# 1                              9               1           1
# 2                             45               0           0
# 3                             12               0           1
# 4                              5               0           1
# ...                          ...             ...         ...
# 1495                          59               1           1
# 1496                          26               1           1
# 1497                          40               0           0
# 1498                          52               1           0
# 1499                           2               1           1
#
# [1500 rows x 7 columns]

# %%
x=df.drop('buy_coffee',axis=1)
y=df['buy_coffee']

# %%
print(x.head)
# Out:
# <bound method NDFrame.head of       current_mood  weather  last_coffee_hours_ago  taste_craving  \
# 0                0        2                    100              1
# 1                1        1                     71              1
# 2                0        2                     29              0
# 3                1        2                     89              1
# 4                2        1                     10              1
# ...            ...      ...                    ...            ...
# 1495             1        2                     43              1
# 1496             0        2                     57              0
# 1497             1        0                     59              0
# 1498             2        1                    103              0
# 1499             1        0                     92              0
#
#       distance_to_coffee_shop_km  social_context
# 0                             36               0
# 1                              9               1
# 2                             45               0
# 3                             12               0
# 4                              5               0
# ...                          ...             ...
# 1495                          59               1
# 1496                          26               1
# 1497                          40               0
# 1498                          52               1
# 1499                           2               1
#
# [1500 rows x 6 columns]>

# %%
print(y.head)
# Out:
# <bound method NDFrame.head of 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 1495    1
# 1496    1
# 1497    0
# 1498    0
# 1499    1
# Name: buy_coffee, Length: 1500, dtype: int64>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (1050, 6)
# (450, 6)

# %%
model=CategoricalNB()
model.fit(x_train,y_train)
# Out:
# CategoricalNB()

# %%
prediction=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,prediction)
print(accuracy*100)
# Out:
# 75.33333333333333
