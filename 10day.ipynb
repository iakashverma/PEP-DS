# %% [markdown]
# CNN
#
# ........................................................................
#
# Steps-
#
# 1. Input image
# 2. image processing
# 3. convolution layer
# 4. Feature map generation
# 5. Activation function (ReLU)
# 6. Pooling layer
# 7. Repeat CNN blocks
# 8. Feature learning
# 9. Flatten Layer
# 10. Fully connected layer
# 11. Output layer
# 12. Softmax function
# 13. Bounding Box prediction (object detection)
# 14.
