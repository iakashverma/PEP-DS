# %% [markdown]
# car price prediction system (PROJECT 1)
#
# pipeline
# 1. install lib (numpy,pandas, matplotlib, scikit-learn)
# 2. importing it
# 3. using dataset
# 4. visualising the dataset
# 5. splitting the dataset
# 6. selection of model - linear regression
# 7. fitting the training data on that model
# 8. prediction on test data
# 9. model evaluation
# 10. checking on new dataset (optional)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('car_price.csv')
print(data.head())
# Out:
#    Mileage  Year    Price
# 0    34184  2020  1612472
# 1    77097  2021  1534130
# 2    41579  2013  1107288
# 3   199161  2020   956991
# 4   159794  2011   483592

# %%
plt.scatter(data['Mileage'], data['Price'])

plt.title('Mileage vs Price')
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.show()

# %%
x = data['Mileage']
y = data['Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

#our data has been splitted guys, now we will train our model using linear regression

# %%
model = LinearRegression()

model.fit(x_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test.values.reshape(-1, 1))
print("Predicted values:", prediction)
# Out:
# Predicted values: [1510886.11246962 1178496.8990753  1010938.07078906 1312233.83766781
#  1217840.50941872  913400.27931285 1487529.55829294 1200724.25597627
#  1626555.89465065 1598914.87425558 1324492.92196734 1048050.30086993
#  1440173.50986393 1186806.49433871 1489139.60991095  820708.851264
#   646347.82503456  686939.49552483 1570187.87944702 1567621.5220022
#  1296317.01865219 1604107.02058077 1480365.36887858  740141.43607023
#  1230110.39943381 1383924.35753142 1328555.87101682 1544335.20497664
#   651286.03704416 1171338.11251872 1353430.62822927  883776.41011305
#  1023029.66649746  745209.31666651  666192.52165518  977823.95546431
#   896273.22015484  719734.84224064 1082525.93635488  932591.23014227]

# %%
print("Mean Squared Error:", mean_squared_error(y_test, prediction))
print("R-squared:", r2_score(y_test, prediction)) #mean of precision and recall
# Out:
# Mean Squared Error: 91807876350.10107
# R-squared: 0.5031443415250028

# %%
new_car_mileage = 50000
predicted_price = model.predict([[new_car_mileage]])
print(f"Predicted price for a car with {new_car_mileage} mileage: {predicted_price[0]}")
# Out:
# Predicted price for a car with 50000 mileage: 1422516.9706436207

# %%
plt.scatter(data['Mileage'], data['Price'])
plt.plot(x_test, prediction, color='green', linewidth=1)
plt.title('Mileage vs Price with Regression Line')
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.show()
